# %%
# 01 10 fold cross validation for  Linear Regression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import make_scorer, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# Load and preprocess data
file_path = r"D:\B TECH COMPUTER SCIENCE AND ENGINEERING\SEMESTER 05\MACHINE LEARNING\ML PROJECT\EMBEDDINGS_GPT2.xlsx"
data = pd.read_excel(file_path)
X = data.iloc[:, 0:768]
y = data['Average_Marks']

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Initialize the model (Example: Linear Regression)
model = LinearRegression()

# Cross-validation for RMSE
neg_mse_scorer = make_scorer(mean_squared_error, greater_is_better=False)
cv_scores_mse = cross_val_score(model, X_scaled, y, cv=10, scoring=neg_mse_scorer)
cv_rmse_scores = np.sqrt(-cv_scores_mse)  # Convert negative MSE to positive RMSE

# Cross-validation for R²
cv_scores_r2 = cross_val_score(model, X_scaled, y, cv=10, scoring='r2')

# Calculate average RMSE and R²
avg_rmse = np.mean(cv_rmse_scores)
avg_r2 = np.mean(cv_scores_r2)

# Display results
print(f"Linear Regression 10-Fold CV - Avg RMSE: {avg_rmse}, Avg R²: {avg_r2}")

# Plotting RMSE and R² across folds in bar plot format
plt.figure(figsize=(12, 6))

# RMSE Bar Plot
plt.subplot(1, 2, 1)
plt.bar(range(1, 11), cv_rmse_scores, color='skyblue', label='RMSE per Fold')
plt.axhline(y=avg_rmse, color='r', linestyle='--', label=f'Average RMSE: {avg_rmse:.2f}')
plt.xlabel('Fold')
plt.ylabel('RMSE')
plt.title('10-Fold Cross-Validation RMSE for Linear Regression')
plt.legend()

# R² Bar Plot
plt.subplot(1, 2, 2)
plt.bar(range(1, 11), cv_scores_r2, color='lightgreen', label='R² per Fold')
plt.axhline(y=avg_r2, color='r', linestyle='--', label=f'Average R²: {avg_r2:.2f}')
plt.xlabel('Fold')
plt.ylabel('R²')
plt.title('10-Fold Cross-Validation R² for Linear Regression')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Linear Regression 10-Fold CV - Avg RMSE: 2.1195346581248056, Avg R²: -34.96801568220532

# %%
# 02 10 fold cross validation for Ridge Regression

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Ridge
from sklearn.metrics import make_scorer, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# Load and preprocess data
file_path = r"D:\B TECH COMPUTER SCIENCE AND ENGINEERING\SEMESTER 05\MACHINE LEARNING\ML PROJECT\EMBEDDINGS_GPT2.xlsx"
data = pd.read_excel(file_path)
X = data.iloc[:, 0:768]
y = data['Average_Marks']

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Initialize the model (Example: Linear Regression)
model = Ridge()

# Cross-validation for RMSE
neg_mse_scorer = make_scorer(mean_squared_error, greater_is_better=False)
cv_scores_mse = cross_val_score(model, X_scaled, y, cv=10, scoring=neg_mse_scorer)
cv_rmse_scores = np.sqrt(-cv_scores_mse)  # Convert negative MSE to positive RMSE

# Cross-validation for R²
cv_scores_r2 = cross_val_score(model, X_scaled, y, cv=10, scoring='r2')

# Calculate average RMSE and R²
avg_rmse = np.mean(cv_rmse_scores)
avg_r2 = np.mean(cv_scores_r2)

# Display results
print(f"Ridge Regression 10-Fold CV - Avg RMSE: {avg_rmse}, Avg R²: {avg_r2}")

# Plotting RMSE and R² across folds in bar plot format
plt.figure(figsize=(12, 6))

# RMSE Bar Plot
plt.subplot(1, 2, 1)
plt.bar(range(1, 11), cv_rmse_scores, color='skyblue', label='RMSE per Fold')
plt.axhline(y=avg_rmse, color='r', linestyle='--', label=f'Average RMSE: {avg_rmse:.2f}')
plt.xlabel('Fold')
plt.ylabel('RMSE')
plt.title('10-Fold Cross-Validation RMSE for Ridge Regression')

# R² Bar Plot
plt.subplot(1, 2, 2)
plt.bar(range(1, 11), cv_scores_r2, color='lightgreen', label='R² per Fold')
plt.axhline(y=avg_r2, color='r', linestyle='--', label=f'Average R²: {avg_r2:.2f}')
plt.xlabel('Fold')
plt.ylabel('R²')
plt.title('10-Fold Cross-Validation R² for Ridge Regression')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Ridge Regression 10-Fold CV - Avg RMSE: 1.7570448789872473, Avg R²: -20.42301049896941

# %%
# 03 10 fold cross validation for ElasticNet Regression

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import ElasticNet
from sklearn.metrics import make_scorer, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# Load and preprocess data
file_path = r"D:\B TECH COMPUTER SCIENCE AND ENGINEERING\SEMESTER 05\MACHINE LEARNING\ML PROJECT\EMBEDDINGS_GPT2.xlsx"
data = pd.read_excel(file_path)
X = data.iloc[:, 0:768]
y = data['Average_Marks']

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Initialize the model (Example: Linear Regression)
model = ElasticNet()

# Cross-validation for RMSE
neg_mse_scorer = make_scorer(mean_squared_error, greater_is_better=False)
cv_scores_mse = cross_val_score(model, X_scaled, y, cv=10, scoring=neg_mse_scorer)
cv_rmse_scores = np.sqrt(-cv_scores_mse)  # Convert negative MSE to positive RMSE

# Cross-validation for R²
cv_scores_r2 = cross_val_score(model, X_scaled, y, cv=10, scoring='r2')

# Calculate average RMSE and R²
avg_rmse = np.mean(cv_rmse_scores)
avg_r2 = np.mean(cv_scores_r2)

# Display results
print(f"ElasticNet Regression 10-Fold CV - Avg RMSE: {avg_rmse}, Avg R²: {avg_r2}")

# Plotting RMSE and R² across folds in bar plot format
plt.figure(figsize=(12, 6))

# RMSE Bar Plot
plt.subplot(1, 2, 1)
plt.bar(range(1, 11), cv_rmse_scores, color='skyblue', label='RMSE per Fold')
plt.axhline(y=avg_rmse, color='r', linestyle='--', label=f'Average RMSE: {avg_rmse:.2f}')
plt.xlabel('Fold')
plt.ylabel('RMSE')
plt.title('10-Fold Cross-Validation RMSE for ElasticNet Regression')

# R² Bar Plot
plt.subplot(1, 2, 2)
plt.bar(range(1, 11), cv_scores_r2, color='lightgreen', label='R² per Fold')
plt.axhline(y=avg_r2, color='r', linestyle='--', label=f'Average R²: {avg_r2:.2f}')
plt.xlabel('Fold')
plt.ylabel('R²')
plt.title('10-Fold Cross-Validation R² for ElasticNet Regression')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ElasticNet Regression 10-Fold CV - Avg RMSE: 1.5227971716711532, Avg R²: -13.11294698724966

# %%
# 04 10 fold cross validation for SVR
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVR
from sklearn.metrics import make_scorer, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# Load and preprocess data
file_path = r"D:\B TECH COMPUTER SCIENCE AND ENGINEERING\SEMESTER 05\MACHINE LEARNING\ML PROJECT\EMBEDDINGS_GPT2.xlsx"
data = pd.read_excel(file_path)
X = data.iloc[:, 0:768]
y = data['Average_Marks']

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Initialize the model (Example: Linear Regression)
model = SVR()

# Cross-validation for RMSE
neg_mse_scorer = make_scorer(mean_squared_error, greater_is_better=False)
cv_scores_mse = cross_val_score(model, X_scaled, y, cv=10, scoring=neg_mse_scorer)
cv_rmse_scores = np.sqrt(-cv_scores_mse)  # Convert negative MSE to positive RMSE

# Cross-validation for R²
cv_scores_r2 = cross_val_score(model, X_scaled, y, cv=10, scoring='r2')

# Calculate average RMSE and R²
avg_rmse = np.mean(cv_rmse_scores)
avg_r2 = np.mean(cv_scores_r2)

# Display results
print(f"SVR 10-Fold CV - Avg RMSE: {avg_rmse}, Avg R²: {avg_r2}")

# Plotting RMSE and R² across folds in bar plot format
plt.figure(figsize=(12, 6))

# RMSE Bar Plot
plt.subplot(1, 2, 1)
plt.bar(range(1, 11), cv_rmse_scores, color='skyblue', label='RMSE per Fold')
plt.axhline(y=avg_rmse, color='r', linestyle='--', label=f'Average RMSE: {avg_rmse:.2f}')
plt.xlabel('Fold')
plt.ylabel('RMSE')
plt.title('10-Fold Cross-Validation RMSE for SVR')
plt.legend()

# R² Bar Plot
plt.subplot(1, 2, 2)
plt.bar(range(1, 11), cv_scores_r2, color='lightgreen', label='R² per Fold')
plt.axhline(y=avg_r2, color='r', linestyle='--', label=f'Average R²: {avg_r2:.2f}')
plt.xlabel('Fold')
plt.ylabel('R²')
plt.title('10-Fold Cross-Validation R² for SVR')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# 05 10 fold cross validation for  Lasso Regression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Lasso
from sklearn.metrics import make_scorer, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# Load and preprocess data
file_path = r"D:\B TECH COMPUTER SCIENCE AND ENGINEERING\SEMESTER 05\MACHINE LEARNING\ML PROJECT\EMBEDDINGS_GPT2.xlsx"
data = pd.read_excel(file_path)
X = data.iloc[:, 0:768]
y = data['Average_Marks']

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Initialize the model (Example: Linear Regression)
model = Lasso()

# Cross-validation for RMSE
neg_mse_scorer = make_scorer(mean_squared_error, greater_is_better=False)
cv_scores_mse = cross_val_score(model, X_scaled, y, cv=10, scoring=neg_mse_scorer)
cv_rmse_scores = np.sqrt(-cv_scores_mse)  # Convert negative MSE to positive RMSE

# Cross-validation for R²
cv_scores_r2 = cross_val_score(model, X_scaled, y, cv=10, scoring='r2')

# Calculate average RMSE and R²
avg_rmse = np.mean(cv_rmse_scores)
avg_r2 = np.mean(cv_scores_r2)

# Display results
print(f" Lasso Regression 10-Fold CV - Avg RMSE: {avg_rmse}, Avg R²: {avg_r2}")

# Plotting RMSE and R² across folds in bar plot format
plt.figure(figsize=(12, 6))

# RMSE Bar Plot
plt.subplot(1, 2, 1)
plt.bar(range(1, 11), cv_rmse_scores, color='skyblue', label='RMSE per Fold')
plt.axhline(y=avg_rmse, color='r', linestyle='--', label=f'Average RMSE: {avg_rmse:.2f}')
plt.xlabel('Fold')
plt.ylabel('RMSE')
plt.title('10-Fold Cross-Validation RMSE for Lasso Regression')
plt.legend()

# R² Bar Plot
plt.subplot(1, 2, 2)
plt.bar(range(1, 11), cv_scores_r2, color='lightgreen', label='R² per Fold')
plt.axhline(y=avg_r2, color='r', linestyle='--', label=f'Average R²: {avg_r2:.2f}')
plt.xlabel('Fold')
plt.ylabel('R²')
plt.title('10-Fold Cross-Validation R² for  Lasso Regression')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# 06 10 fold cross validation for Random Forest Regression 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import make_scorer, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# Load and preprocess data
file_path = r"D:\B TECH COMPUTER SCIENCE AND ENGINEERING\SEMESTER 05\MACHINE LEARNING\ML PROJECT\EMBEDDINGS_GPT2.xlsx"
data = pd.read_excel(file_path)
X = data.iloc[:, 0:768]
y = data['Average_Marks']

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Initialize the model (Example: Linear Regression)
model = RandomForestRegressor()

# Cross-validation for RMSE
neg_mse_scorer = make_scorer(mean_squared_error, greater_is_better=False)
cv_scores_mse = cross_val_score(model, X_scaled, y, cv=10, scoring=neg_mse_scorer)
cv_rmse_scores = np.sqrt(-cv_scores_mse)  # Convert negative MSE to positive RMSE

# Cross-validation for R²
cv_scores_r2 = cross_val_score(model, X_scaled, y, cv=10, scoring='r2')

# Calculate average RMSE and R²
avg_rmse = np.mean(cv_rmse_scores)
avg_r2 = np.mean(cv_scores_r2)

# Display results
print(f"Random Forest Regression 10-Fold CV - Avg RMSE: {avg_rmse}, Avg R²: {avg_r2}")

# Plotting RMSE and R² across folds in bar plot format
plt.figure(figsize=(12, 6))

# RMSE Bar Plot
plt.subplot(1, 2, 1)
plt.bar(range(1, 11), cv_rmse_scores, color='skyblue', label='RMSE per Fold')
plt.axhline(y=avg_rmse, color='r', linestyle='--', label=f'Average RMSE: {avg_rmse:.2f}')
plt.xlabel('Fold')
plt.ylabel('RMSE')
plt.title('10-Fold Cross-Validation RMSE for Random Forest Regression ')
plt.legend()

# R² Bar Plot
plt.subplot(1, 2, 2)
plt.bar(range(1, 11), cv_scores_r2, color='lightgreen', label='R² per Fold')
plt.axhline(y=avg_r2, color='r', linestyle='--', label=f'Average R²: {avg_r2:.2f}')
plt.xlabel('Fold')
plt.ylabel('R²')
plt.title('10-Fold Cross-Validation R² for Random Forest Regression ')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# 07 10 fold cross validation for  Gradient Boosting Regression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import make_scorer, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# Load and preprocess data
file_path = r"D:\B TECH COMPUTER SCIENCE AND ENGINEERING\SEMESTER 05\MACHINE LEARNING\ML PROJECT\EMBEDDINGS_GPT2.xlsx"
data = pd.read_excel(file_path)
X = data.iloc[:, 0:768]
y = data['Average_Marks']

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Initialize the model (Example: Linear Regression)
model = GradientBoostingRegressor()

# Cross-validation for RMSE
neg_mse_scorer = make_scorer(mean_squared_error, greater_is_better=False)
cv_scores_mse = cross_val_score(model, X_scaled, y, cv=10, scoring=neg_mse_scorer)
cv_rmse_scores = np.sqrt(-cv_scores_mse)  # Convert negative MSE to positive RMSE

# Cross-validation for R²
cv_scores_r2 = cross_val_score(model, X_scaled, y, cv=10, scoring='r2')

# Calculate average RMSE and R²
avg_rmse = np.mean(cv_rmse_scores)
avg_r2 = np.mean(cv_scores_r2)

# Display results
print(f"Gradient Boosting Regression 10-Fold CV - Avg RMSE: {avg_rmse}, Avg R²: {avg_r2}")

# Plotting RMSE and R² across folds in bar plot format
plt.figure(figsize=(12, 6))

# RMSE Bar Plot
plt.subplot(1, 2, 1)
plt.bar(range(1, 11), cv_rmse_scores, color='skyblue', label='RMSE per Fold')
plt.axhline(y=avg_rmse, color='r', linestyle='--', label=f'Average RMSE: {avg_rmse:.2f}')
plt.xlabel('Fold')
plt.ylabel('RMSE')
plt.title('10-Fold Cross-Validation RMSE for Gradient Boosting Regression')
plt.legend()

# R² Bar Plot
plt.subplot(1, 2, 2)
plt.bar(range(1, 11), cv_scores_r2, color='lightgreen', label='R² per Fold')
plt.axhline(y=avg_r2, color='r', linestyle='--', label=f'Average R²: {avg_r2:.2f}')
plt.xlabel('Fold')
plt.ylabel('R²')
plt.title('10-Fold Cross-Validation R² for Gradient Boosting Regression')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# 08 10 fold cross validation for K-Nearest Neighbors Regression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import make_scorer, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# Load and preprocess data
file_path = r"D:\B TECH COMPUTER SCIENCE AND ENGINEERING\SEMESTER 05\MACHINE LEARNING\ML PROJECT\EMBEDDINGS_GPT2.xlsx"
data = pd.read_excel(file_path)
X = data.iloc[:, 0:768]
y = data['Average_Marks']

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Initialize the model (Example: Linear Regression)
model = KNeighborsRegressor()

# Cross-validation for RMSE
neg_mse_scorer = make_scorer(mean_squared_error, greater_is_better=False)
cv_scores_mse = cross_val_score(model, X_scaled, y, cv=10, scoring=neg_mse_scorer)
cv_rmse_scores = np.sqrt(-cv_scores_mse)  # Convert negative MSE to positive RMSE

# Cross-validation for R²
cv_scores_r2 = cross_val_score(model, X_scaled, y, cv=10, scoring='r2')

# Calculate average RMSE and R²
avg_rmse = np.mean(cv_rmse_scores)
avg_r2 = np.mean(cv_scores_r2)

# Display results
print(f"K-Nearest Neighbors Regression 10-Fold CV - Avg RMSE: {avg_rmse}, Avg R²: {avg_r2}")

# Plotting RMSE and R² across folds in bar plot format
plt.figure(figsize=(12, 6))

# RMSE Bar Plot
plt.subplot(1, 2, 1)
plt.bar(range(1, 11), cv_rmse_scores, color='skyblue', label='RMSE per Fold')
plt.axhline(y=avg_rmse, color='r', linestyle='--', label=f'Average RMSE: {avg_rmse:.2f}')
plt.xlabel('Fold')
plt.ylabel('RMSE')
plt.title('10-Fold Cross-Validation RMSE for K-Nearest Neighbors Regression')
plt.legend()

# R² Bar Plot
plt.subplot(1, 2, 2)
plt.bar(range(1, 11), cv_scores_r2, color='lightgreen', label='R² per Fold')
plt.axhline(y=avg_r2, color='r', linestyle='--', label=f'Average R²: {avg_r2:.2f}')
plt.xlabel('Fold')
plt.ylabel('R²')
plt.title('10-Fold Cross-Validation R² for K-Nearest Neighbors Regression')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# 09 10 fold cross validation for Polynomial Regression (2nd Degree)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression
from sklearn.metrics import make_scorer, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# Load and preprocess data
file_path = r"D:\B TECH COMPUTER SCIENCE AND ENGINEERING\SEMESTER 05\MACHINE LEARNING\ML PROJECT\EMBEDDINGS_GPT2.xlsx"
data = pd.read_excel(file_path)
X = data.iloc[:, 0:768]
y = data['Average_Marks']

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Initialize the model (Example: Linear Regression)
model = make_pipeline(PolynomialFeatures(degree=2), LinearRegression())

# Cross-validation for RMSE
neg_mse_scorer = make_scorer(mean_squared_error, greater_is_better=False)
cv_scores_mse = cross_val_score(model, X_scaled, y, cv=10, scoring=neg_mse_scorer)
cv_rmse_scores = np.sqrt(-cv_scores_mse)  # Convert negative MSE to positive RMSE

# Cross-validation for R²
cv_scores_r2 = cross_val_score(model, X_scaled, y, cv=10, scoring='r2')

# Calculate average RMSE and R²
avg_rmse = np.mean(cv_rmse_scores)
avg_r2 = np.mean(cv_scores_r2)

# Display results
print(f"Polynomial Regression (2nd Degree) 10-Fold CV - Avg RMSE: {avg_rmse}, Avg R²: {avg_r2}")

# Plotting RMSE and R² across folds in bar plot format
plt.figure(figsize=(12, 6))

# RMSE Bar Plot
plt.subplot(1, 2, 1)
plt.bar(range(1, 11), cv_rmse_scores, color='skyblue', label='RMSE per Fold')
plt.axhline(y=avg_rmse, color='r', linestyle='--', label=f'Average RMSE: {avg_rmse:.2f}')
plt.xlabel('Fold')
plt.ylabel('RMSE')
plt.title('10-Fold Cross-Validation RMSE for Polynomial Regression (2nd Degree)')
plt.legend()

# R² Bar Plot
plt.subplot(1, 2, 2)
plt.bar(range(1, 11), cv_scores_r2, color='lightgreen', label='R² per Fold')
plt.axhline(y=avg_r2, color='r', linestyle='--', label=f'Average R²: {avg_r2:.2f}')
plt.xlabel('Fold')
plt.ylabel('R²')
plt.title('10-Fold Cross-Validation R² for Polynomial Regression (2nd Degree)')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# 10 10 fold cross validation for Decision Tree Regression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import make_scorer, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# Load and preprocess data
file_path = r"D:\B TECH COMPUTER SCIENCE AND ENGINEERING\SEMESTER 05\MACHINE LEARNING\ML PROJECT\EMBEDDINGS_GPT2.xlsx"
data = pd.read_excel(file_path)
X = data.iloc[:, 0:768]
y = data['Average_Marks']

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Initialize the model (Example: Linear Regression)
model = DecisionTreeRegressor()

# Cross-validation for RMSE
neg_mse_scorer = make_scorer(mean_squared_error, greater_is_better=False)
cv_scores_mse = cross_val_score(model, X_scaled, y, cv=10, scoring=neg_mse_scorer)
cv_rmse_scores = np.sqrt(-cv_scores_mse)  # Convert negative MSE to positive RMSE

# Cross-validation for R²
cv_scores_r2 = cross_val_score(model, X_scaled, y, cv=10, scoring='r2')

# Calculate average RMSE and R²
avg_rmse = np.mean(cv_rmse_scores)
avg_r2 = np.mean(cv_scores_r2)

# Display results
print(f"Decision Tree Regression 10-Fold CV - Avg RMSE: {avg_rmse}, Avg R²: {avg_r2}")

# Plotting RMSE and R² across folds in bar plot format
plt.figure(figsize=(12, 6))

# RMSE Bar Plot
plt.subplot(1, 2, 1)
plt.bar(range(1, 11), cv_rmse_scores, color='skyblue', label='RMSE per Fold')
plt.axhline(y=avg_rmse, color='r', linestyle='--', label=f'Average RMSE: {avg_rmse:.2f}')
plt.xlabel('Fold')
plt.ylabel('RMSE')
plt.title('10-Fold Cross-Validation RMSE for Decision Tree Regression')
plt.legend()

# R² Bar Plot
plt.subplot(1, 2, 2)
plt.bar(range(1, 11), cv_scores_r2, color='lightgreen', label='R² per Fold')
plt.axhline(y=avg_r2, color='r', linestyle='--', label=f'Average R²: {avg_r2:.2f}')
plt.xlabel('Fold')
plt.ylabel('R²')
plt.title('10-Fold Cross-Validation R² for Decision Tree Regression')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Decision Tree Regression 10-Fold CV - Avg RMSE: 1.8484831042204923, Avg R²: -25.663464411810065

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures

# Load and preprocess data
file_path = r"D:\B TECH COMPUTER SCIENCE AND ENGINEERING\SEMESTER 05\MACHINE LEARNING\ML PROJECT\EMBEDDINGS_GPT2.xlsx"
data = pd.read_excel(file_path)
X = data.iloc[:, 0:768]
y = data['Average_Marks']

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Define models
models = {
    "Linear Regression": LinearRegression(),
    "Ridge Regression": Ridge(),
    "Lasso Regression": Lasso(),
    "ElasticNet Regression": ElasticNet(),
    "SVR": SVR(),
    "Decision Tree": DecisionTreeRegressor(),
    "Random Forest": RandomForestRegressor(),
    "Gradient Boosting": GradientBoostingRegressor(),
    "K-Nearest Neighbors": KNeighborsRegressor(),
    "Polynomial Regression (2nd Degree)": make_pipeline(PolynomialFeatures(degree=2), LinearRegression())
}

# Initialize lists to store results
model_names = []
avg_rmse_scores = []
avg_r2_scores = []

# Perform 10-fold cross-validation for each model
for name, model in models.items():
    # Cross-validation for RMSE
    neg_mse_scorer = make_scorer(mean_squared_error, greater_is_better=False)
    cv_scores_mse = cross_val_score(model, X_scaled, y, cv=10, scoring=neg_mse_scorer)
    cv_rmse_scores = np.sqrt(-cv_scores_mse)  # Convert negative MSE to positive RMSE

    # Cross-validation for R²
    cv_scores_r2 = cross_val_score(model, X_scaled, y, cv=10, scoring='r2')

    # Calculate and store average RMSE and R²
    avg_rmse = np.mean(cv_rmse_scores)
    avg_r2 = np.mean(cv_scores_r2)
    model_names.append(name)
    avg_rmse_scores.append(avg_rmse)
    avg_r2_scores.append(avg_r2)

# Create a DataFrame to hold results
cv_results_df = pd.DataFrame({
    "Model": model_names,
    "Avg RMSE (10-fold)": avg_rmse_scores,
    "Avg R² (10-fold)": avg_r2_scores
})

# Display the cross-validation performance DataFrame
print(cv_results_df)

# Plotting RMSE and R² scores for each model
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# RMSE Bar Plot
axes[0].barh(model_names, avg_rmse_scores, color='skyblue', edgecolor='black')
axes[0].set_xlabel('Average RMSE (10-fold)')
axes[0].set_title('10-Fold Cross-Validation RMSE for Different Regression Algorithms')

# R² Bar Plot
axes[1].barh(model_names, avg_r2_scores, color='lightgreen', edgecolor='black')
axes[1].set_xlabel('Average R² (10-fold)')
axes[1].set_title('10-Fold Cross-Validation R² for Different Regression Algorithms')

plt.tight_layout()
plt.show()
# Out:
#                                 Model  Avg RMSE (10-fold)  Avg R² (10-fold)
# 0                   Linear Regression        2.119535e+00     -3.496802e+01
# 1                    Ridge Regression        1.757045e+00     -2.042301e+01
# 2                    Lasso Regression        1.579964e+00     -1.523220e+01
# 3               ElasticNet Regression        1.522797e+00     -1.311295e+01
# 4                                 SVR        1.625690e+00     -1.583374e+01
# 5                       Decision Tree        1.848246e+00     -2.809216e+01
# 6                       Random Forest        1.527212e+00     -1.307856e+01
# 7                   Gradient Boosting        1.535994e+00     -1.308921e+01
# 8                 K-Nearest Neighbors        1.650824e+00     -1.572607e+01
# 9  Polynomial Regression (2nd Degree)        3.381627e+10     -5.395972e+21
