# %%
# 01 Linear Regression
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Load data
file_path = r"D:\B TECH COMPUTER SCIENCE AND ENGINEERING\SEMESTER 05\MACHINE LEARNING\ML PROJECT\EMBEDDINGS_GPT2.xlsx"
data = pd.read_excel(file_path)

# Features and target variable
X = data.iloc[:, 0:768]
y = data['Average_Marks']

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Model and threshold
model = LinearRegression()
threshold = 50

# Train and predict
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# Regression metrics
mse = mean_squared_error(y_test, y_pred)
rmse = mse ** 0.5
r2 = r2_score(y_test, y_pred)

# Convert predictions to binary classes based on threshold
y_pred_classes = (y_pred >= threshold).astype(int)
y_test_classes = (y_test >= threshold).astype(int)

# Classification metrics
accuracy = accuracy_score(y_test_classes, y_pred_classes)
precision = precision_score(y_test_classes, y_pred_classes, zero_division=0)
recall = recall_score(y_test_classes, y_pred_classes, zero_division=0)
f1 = f1_score(y_test_classes, y_pred_classes, zero_division=0)
conf_matrix = confusion_matrix(y_test_classes, y_pred_classes)

# Display regression metrics
print("Linear Regression Performance:")
print(f"MSE: {mse}, RMSE: {rmse}, R²: {r2}")
print(f"Accuracy: {accuracy}, Precision: {precision}, Recall: {recall}, F1 Score: {f1}")

# Plot confusion matrix with a colorful palette
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="YlGnBu", cbar=True, annot_kws={"size": 14},
            xticklabels=["Predicted Negative", "Predicted Positive"], 
            yticklabels=["Actual Negative", "Actual Positive"],
            linewidths=1, linecolor='black', square=True)

plt.xlabel("Predicted Class")
plt.ylabel("Actual Class")
plt.title("Confusion Matrix with Colors")
plt.show()

# Plot classification metrics
classification_metrics = {
    "Accuracy": accuracy,
    "Precision": precision,
    "Recall": recall,
    "F1 Score": f1
}

# Convert metrics dictionary to DataFrame for plotting
metrics_df = pd.DataFrame(list(classification_metrics.items()), columns=["Metric", "Score"])

# Plot the classification metrics
plt.figure(figsize=(8, 5))
sns.barplot(data=metrics_df, x="Metric", y="Score", palette="coolwarm")
plt.title("Classification Metrics for Linear Regression")
plt.ylabel("Score")
plt.ylim(0, 1)  # Assuming scores are within 0-1
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Linear Regression Performance:
# MSE: 3.285151313307191, RMSE: 1.8124986381531962, R²: -0.31404785195772544
# Accuracy: 1.0, Precision: 0.0, Recall: 0.0, F1 Score: 0.0
# C:\Users\sanay\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# C:\Users\sanay\AppData\Local\Temp\ipykernel_15088\1473179467.py:80: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=metrics_df, x="Metric", y="Score", palette="coolwarm")

# %%
# 02 Ridge Regression
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Load data
file_path = r"D:\B TECH COMPUTER SCIENCE AND ENGINEERING\SEMESTER 05\MACHINE LEARNING\ML PROJECT\EMBEDDINGS_GPT2.xlsx"
data = pd.read_excel(file_path)

# Features and target variable
X = data.iloc[:, 0:768]
y = data['Average_Marks']

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Model and threshold
model = Ridge()
threshold = 50

# Train and predict
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# Regression metrics
mse = mean_squared_error(y_test, y_pred)
rmse = mse ** 0.5
r2 = r2_score(y_test, y_pred)

# Convert predictions to binary classes based on threshold
y_pred_classes = (y_pred >= threshold).astype(int)
y_test_classes = (y_test >= threshold).astype(int)

# Classification metrics
accuracy = accuracy_score(y_test_classes, y_pred_classes)
precision = precision_score(y_test_classes, y_pred_classes, zero_division=0)
recall = recall_score(y_test_classes, y_pred_classes, zero_division=0)
f1 = f1_score(y_test_classes, y_pred_classes, zero_division=0)
conf_matrix = confusion_matrix(y_test_classes, y_pred_classes)

# Display regression metrics
print("Ridge Regression Performance:")
print(f"MSE: {mse}, RMSE: {rmse}, R²: {r2}")
print(f"Accuracy: {accuracy}, Precision: {precision}, Recall: {recall}, F1 Score: {f1}")

# Plot confusion matrix with a colorful palette
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="YlGnBu", cbar=True, annot_kws={"size": 14},
            xticklabels=["Predicted Negative", "Predicted Positive"], 
            yticklabels=["Actual Negative", "Actual Positive"],
            linewidths=1, linecolor='black', square=True)

plt.xlabel("Predicted Class")
plt.ylabel("Actual Class")
plt.title("Confusion Matrix with Colors")
plt.show()

# Plot classification metrics
classification_metrics = {
    "Accuracy": accuracy,
    "Precision": precision,
    "Recall": recall,
    "F1 Score": f1                                             
}

# Convert metrics dictionary to DataFrame for plotting
metrics_df = pd.DataFrame(list(classification_metrics.items()), columns=["Metric", "Score"])

# Plot the classification metrics
plt.figure(figsize=(8, 5))
sns.barplot(data=metrics_df, x="Metric", y="Score", palette="coolwarm")
plt.title("Classification Metrics for Ridge Regression")
plt.ylabel("Score")
plt.ylim(0, 1)  # Assuming scores are within 0-1
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sanay\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# Ridge Regression Performance:
# MSE: 2.044133358853745, RMSE: 1.4297319185265973, R²: 0.18235454225918601
# Accuracy: 1.0, Precision: 0.0, Recall: 0.0, F1 Score: 0.0
# C:\Users\sanay\AppData\Local\Temp\ipykernel_13848\3374744587.py:80: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=metrics_df, x="Metric", y="Score", palette="coolwarm")

# %%
# 03 ElasticNet Regression
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import ElasticNet
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Load data
file_path = r"D:\B TECH COMPUTER SCIENCE AND ENGINEERING\SEMESTER 05\MACHINE LEARNING\ML PROJECT\EMBEDDINGS_GPT2.xlsx"
data = pd.read_excel(file_path)

# Features and target variable
X = data.iloc[:, 0:768]
y = data['Average_Marks']

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Model and threshold
model = ElasticNet()
threshold = 50

# Train and predict
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# Regression metrics
mse = mean_squared_error(y_test, y_pred)
rmse = mse ** 0.5
r2 = r2_score(y_test, y_pred)

# Convert predictions to binary classes based on threshold
y_pred_classes = (y_pred >= threshold).astype(int)
y_test_classes = (y_test >= threshold).astype(int)

# Classification metrics
accuracy = accuracy_score(y_test_classes, y_pred_classes)
precision = precision_score(y_test_classes, y_pred_classes, zero_division=0)
recall = recall_score(y_test_classes, y_pred_classes, zero_division=0)
f1 = f1_score(y_test_classes, y_pred_classes, zero_division=0)
conf_matrix = confusion_matrix(y_test_classes, y_pred_classes)

# Display regression metrics
print("ElasticNet Regression Performance:")
print(f"MSE: {mse}, RMSE: {rmse}, R²: {r2}")
print(f"Accuracy: {accuracy}, Precision: {precision}, Recall: {recall}, F1 Score: {f1}")

# Plot confusion matrix with a colorful palette
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="YlGnBu", cbar=True, annot_kws={"size": 14},
            xticklabels=["Predicted Negative", "Predicted Positive"], 
            yticklabels=["Actual Negative", "Actual Positive"],
            linewidths=1, linecolor='black', square=True)

plt.xlabel("Predicted Class")
plt.ylabel("Actual Class")
plt.title("Confusion Matrix with Colors")
plt.show()

# Plot classification metrics
classification_metrics = {
    "Accuracy": accuracy,
    "Precision": precision,
    "Recall": recall,
    "F1 Score": f1                                             
}

# Convert metrics dictionary to DataFrame for plotting
metrics_df = pd.DataFrame(list(classification_metrics.items()), columns=["Metric", "Score"])

# Plot the classification metrics
plt.figure(figsize=(8, 5))
sns.barplot(data=metrics_df, x="Metric", y="Score", palette="coolwarm")
plt.title("Classification Metrics for ElasticNet Regression")
plt.ylabel("Score")
plt.ylim(0, 1)  # Assuming scores are within 0-1
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ElasticNet Regression Performance:
# MSE: 2.1142360393654758, RMSE: 1.4540412784255734, R²: 0.15431374049466018
# Accuracy: 1.0, Precision: 0.0, Recall: 0.0, F1 Score: 0.0
# C:\Users\sanay\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# C:\Users\sanay\AppData\Local\Temp\ipykernel_13848\1914539708.py:80: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=metrics_df, x="Metric", y="Score", palette="coolwarm")

# %%
# 04 SVR
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Load data
file_path = r"D:\B TECH COMPUTER SCIENCE AND ENGINEERING\SEMESTER 05\MACHINE LEARNING\ML PROJECT\EMBEDDINGS_GPT2.xlsx"
data = pd.read_excel(file_path)

# Features and target variable
X = data.iloc[:, 0:768]
y = data['Average_Marks']

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Model and threshold
model = SVR()
threshold = 50

# Train and predict
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# Regression metrics
mse = mean_squared_error(y_test, y_pred)
rmse = mse ** 0.5
r2 = r2_score(y_test, y_pred)

# Convert predictions to binary classes based on threshold
y_pred_classes = (y_pred >= threshold).astype(int)
y_test_classes = (y_test >= threshold).astype(int)

# Classification metrics
accuracy = accuracy_score(y_test_classes, y_pred_classes)
precision = precision_score(y_test_classes, y_pred_classes, zero_division=0)
recall = recall_score(y_test_classes, y_pred_classes, zero_division=0)
f1 = f1_score(y_test_classes, y_pred_classes, zero_division=0)
conf_matrix = confusion_matrix(y_test_classes, y_pred_classes)

# Display regression metrics
print("SVR Performance:")
print(f"MSE: {mse}, RMSE: {rmse}, R²: {r2}")
print(f"Accuracy: {accuracy}, Precision: {precision}, Recall: {recall}, F1 Score: {f1}")

# Plot confusion matrix with a colorful palette
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="YlGnBu", cbar=True, annot_kws={"size": 14},
            xticklabels=["Predicted Negative", "Predicted Positive"], 
            yticklabels=["Actual Negative", "Actual Positive"],
            linewidths=1, linecolor='black', square=True)

plt.xlabel("Predicted Class")
plt.ylabel("Actual Class")
plt.title("Confusion Matrix with Colors")
plt.show()

# Plot classification metrics
classification_metrics = {
    "Accuracy": accuracy,
    "Precision": precision,
    "Recall": recall,
    "F1 Score": f1                                             
}

# Convert metrics dictionary to DataFrame for plotting
metrics_df = pd.DataFrame(list(classification_metrics.items()), columns=["Metric", "Score"])

# Plot the classification metrics
plt.figure(figsize=(8, 5))
sns.barplot(data=metrics_df, x="Metric", y="Score", palette="coolwarm")
plt.title("Classification Metrics for SVR")
plt.ylabel("Score")
plt.ylim(0, 1)  # Assuming scores are within 0-1
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# SVR Performance:
# MSE: 1.5811237084312642, RMSE: 1.2574274167645878, R²: 0.36755661624245706
# Accuracy: 1.0, Precision: 0.0, Recall: 0.0, F1 Score: 0.0
# C:\Users\sanay\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# C:\Users\sanay\AppData\Local\Temp\ipykernel_13848\1068583279.py:80: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=metrics_df, x="Metric", y="Score", palette="coolwarm")

# %%
# 05 Lasso Regression
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Load data
file_path = r"D:\B TECH COMPUTER SCIENCE AND ENGINEERING\SEMESTER 05\MACHINE LEARNING\ML PROJECT\EMBEDDINGS_GPT2.xlsx"
data = pd.read_excel(file_path)

# Features and target variable
X = data.iloc[:, 0:768]
y = data['Average_Marks']

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Model and threshold
model = Lasso()
threshold = 50

# Train and predict
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# Regression metrics
mse = mean_squared_error(y_test, y_pred)
rmse = mse ** 0.5
r2 = r2_score(y_test, y_pred)

# Convert predictions to binary classes based on threshold
y_pred_classes = (y_pred >= threshold).astype(int)
y_test_classes = (y_test >= threshold).astype(int)

# Classification metrics
accuracy = accuracy_score(y_test_classes, y_pred_classes)
precision = precision_score(y_test_classes, y_pred_classes, zero_division=0)
recall = recall_score(y_test_classes, y_pred_classes, zero_division=0)
f1 = f1_score(y_test_classes, y_pred_classes, zero_division=0)
conf_matrix = confusion_matrix(y_test_classes, y_pred_classes)

# Display regression metrics
print("Lasso Regression Performance:")
print(f"MSE: {mse}, RMSE: {rmse}, R²: {r2}")
print(f"Accuracy: {accuracy}, Precision: {precision}, Recall: {recall}, F1 Score: {f1}")

# Plot confusion matrix with a colorful palette
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="YlGnBu", cbar=True, annot_kws={"size": 14},
            xticklabels=["Predicted Negative", "Predicted Positive"], 
            yticklabels=["Actual Negative", "Actual Positive"],
            linewidths=1, linecolor='black', square=True)

plt.xlabel("Predicted Class")
plt.ylabel("Actual Class")
plt.title("Confusion Matrix with Colors")
plt.show()

# Plot classification metrics
classification_metrics = {
    "Accuracy": accuracy,
    "Precision": precision,
    "Recall": recall,
    "F1 Score": f1                                             
}

# Convert metrics dictionary to DataFrame for plotting
metrics_df = pd.DataFrame(list(classification_metrics.items()), columns=["Metric", "Score"])

# Plot the classification metrics
plt.figure(figsize=(8, 5))
sns.barplot(data=metrics_df, x="Metric", y="Score", palette="coolwarm")
plt.title("Classification Metrics for Lasso Regression")
plt.ylabel("Score")
plt.ylim(0, 1)  # Assuming scores are within 0-1
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Lasso Regression Performance:
# MSE: 2.5114424253722762, RMSE: 1.5847531118039415, R²: -0.004567281576337789
# Accuracy: 1.0, Precision: 0.0, Recall: 0.0, F1 Score: 0.0
# C:\Users\sanay\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# C:\Users\sanay\AppData\Local\Temp\ipykernel_13848\1813205171.py:80: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=metrics_df, x="Metric", y="Score", palette="coolwarm")

# %%
# 06 Random Forest Regression   
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Load data
file_path = r"D:\B TECH COMPUTER SCIENCE AND ENGINEERING\SEMESTER 05\MACHINE LEARNING\ML PROJECT\EMBEDDINGS_GPT2.xlsx"
data = pd.read_excel(file_path)

# Features and target variable
X = data.iloc[:, 0:768]
y = data['Average_Marks']

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Model and threshold
model = RandomForestRegressor()
threshold = 50

# Train and predict
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# Regression metrics
mse = mean_squared_error(y_test, y_pred)
rmse = mse ** 0.5
r2 = r2_score(y_test, y_pred)

# Convert predictions to binary classes based on threshold
y_pred_classes = (y_pred >= threshold).astype(int)
y_test_classes = (y_test >= threshold).astype(int)

# Classification metrics
accuracy = accuracy_score(y_test_classes, y_pred_classes)
precision = precision_score(y_test_classes, y_pred_classes, zero_division=0)
recall = recall_score(y_test_classes, y_pred_classes, zero_division=0)
f1 = f1_score(y_test_classes, y_pred_classes, zero_division=0)
conf_matrix = confusion_matrix(y_test_classes, y_pred_classes)

# Display regression metrics
print("Random Forest Regression Performance:")
print(f"MSE: {mse}, RMSE: {rmse}, R²: {r2}")
print(f"Accuracy: {accuracy}, Precision: {precision}, Recall: {recall}, F1 Score: {f1}")

# Plot confusion matrix with a colorful palette
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="YlGnBu", cbar=True, annot_kws={"size": 14},
            xticklabels=["Predicted Negative", "Predicted Positive"], 
            yticklabels=["Actual Negative", "Actual Positive"],
            linewidths=1, linecolor='black', square=True)

plt.xlabel("Predicted Class")
plt.ylabel("Actual Class")
plt.title("Confusion Matrix with Colors")
plt.show()

# Plot classification metrics
classification_metrics = {
    "Accuracy": accuracy,
    "Precision": precision,
    "Recall": recall,
    "F1 Score": f1                                             
}

# Convert metrics dictionary to DataFrame for plotting
metrics_df = pd.DataFrame(list(classification_metrics.items()), columns=["Metric", "Score"])

# Plot the classification metrics
plt.figure(figsize=(8, 5))
sns.barplot(data=metrics_df, x="Metric", y="Score", palette="coolwarm")
plt.title("Classification Metrics for Random Forest Regression  ")
plt.ylabel("Score")
plt.ylim(0, 1)  # Assuming scores are within 0-1
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sanay\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# Random Forest Regression Performance:
# MSE: 1.6458583970731522, RMSE: 1.2829101282136455, R²: 0.3416629905173789
# Accuracy: 1.0, Precision: 0.0, Recall: 0.0, F1 Score: 0.0
# C:\Users\sanay\AppData\Local\Temp\ipykernel_13848\3209616258.py:80: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=metrics_df, x="Metric", y="Score", palette="coolwarm")

# %%
# 07 Gradient Boosting Regression
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Load data
file_path = r"D:\B TECH COMPUTER SCIENCE AND ENGINEERING\SEMESTER 05\MACHINE LEARNING\ML PROJECT\EMBEDDINGS_GPT2.xlsx"
data = pd.read_excel(file_path)

# Features and target variable
X = data.iloc[:, 0:768]
y = data['Average_Marks']

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Model and threshold
model = GradientBoostingRegressor()
threshold = 50

# Train and predict
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# Regression metrics
mse = mean_squared_error(y_test, y_pred)
rmse = mse ** 0.5
r2 = r2_score(y_test, y_pred)

# Convert predictions to binary classes based on threshold
y_pred_classes = (y_pred >= threshold).astype(int)
y_test_classes = (y_test >= threshold).astype(int)

# Classification metrics
accuracy = accuracy_score(y_test_classes, y_pred_classes)
precision = precision_score(y_test_classes, y_pred_classes, zero_division=0)
recall = recall_score(y_test_classes, y_pred_classes, zero_division=0)
f1 = f1_score(y_test_classes, y_pred_classes, zero_division=0)
conf_matrix = confusion_matrix(y_test_classes, y_pred_classes)

# Display regression metrics
print("Gradient Boosting Regression Performance:")
print(f"MSE: {mse}, RMSE: {rmse}, R²: {r2}")
print(f"Accuracy: {accuracy}, Precision: {precision}, Recall: {recall}, F1 Score: {f1}")

# Plot confusion matrix with a colorful palette
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="YlGnBu", cbar=True, annot_kws={"size": 14},
            xticklabels=["Predicted Negative", "Predicted Positive"], 
            yticklabels=["Actual Negative", "Actual Positive"],
            linewidths=1, linecolor='black', square=True)

plt.xlabel("Predicted Class")
plt.ylabel("Actual Class")
plt.title("Confusion Matrix with Colors")
plt.show()

# Plot classification metrics
classification_metrics = {
    "Accuracy": accuracy,
    "Precision": precision,
    "Recall": recall,
    "F1 Score": f1                                             
}

# Convert metrics dictionary to DataFrame for plotting
metrics_df = pd.DataFrame(list(classification_metrics.items()), columns=["Metric", "Score"])

# Plot the classification metrics
plt.figure(figsize=(8, 5))
sns.barplot(data=metrics_df, x="Metric", y="Score", palette="coolwarm")
plt.title("Classification Metrics for Gradient Boosting Regression")
plt.ylabel("Score")
plt.ylim(0, 1)  # Assuming scores are within 0-1
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sanay\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# Gradient Boosting Regression Performance:
# MSE: 1.636258132383184, RMSE: 1.2791630593412178, R²: 0.34550305935773273
# Accuracy: 1.0, Precision: 0.0, Recall: 0.0, F1 Score: 0.0
# C:\Users\sanay\AppData\Local\Temp\ipykernel_13848\3458601745.py:80: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=metrics_df, x="Metric", y="Score", palette="coolwarm")

# %%
# 08 K-Nearest Neighbors Regression
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Load data
file_path = r"D:\B TECH COMPUTER SCIENCE AND ENGINEERING\SEMESTER 05\MACHINE LEARNING\ML PROJECT\EMBEDDINGS_GPT2.xlsx"
data = pd.read_excel(file_path)

# Features and target variable
X = data.iloc[:, 0:768]
y = data['Average_Marks']

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Model and threshold
model = KNeighborsRegressor()
threshold = 50

# Train and predict
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# Regression metrics
mse = mean_squared_error(y_test, y_pred)
rmse = mse ** 0.5
r2 = r2_score(y_test, y_pred)

# Convert predictions to binary classes based on threshold
y_pred_classes = (y_pred >= threshold).astype(int)
y_test_classes = (y_test >= threshold).astype(int)

# Classification metrics
accuracy = accuracy_score(y_test_classes, y_pred_classes)
precision = precision_score(y_test_classes, y_pred_classes, zero_division=0)
recall = recall_score(y_test_classes, y_pred_classes, zero_division=0)
f1 = f1_score(y_test_classes, y_pred_classes, zero_division=0)
conf_matrix = confusion_matrix(y_test_classes, y_pred_classes)

# Display regression metrics
print(" K-Nearest Neighbors Regression Performance:")
print(f"MSE: {mse}, RMSE: {rmse}, R²: {r2}")
print(f"Accuracy: {accuracy}, Precision: {precision}, Recall: {recall}, F1 Score: {f1}")

# Plot confusion matrix with a colorful palette
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="YlGnBu", cbar=True, annot_kws={"size": 14},
            xticklabels=["Predicted Negative", "Predicted Positive"], 
            yticklabels=["Actual Negative", "Actual Positive"],
            linewidths=1, linecolor='black', square=True)

plt.xlabel("Predicted Class")
plt.ylabel("Actual Class")
plt.title("Confusion Matrix with Colors")
plt.show()

# Plot classification metrics
classification_metrics = {
    "Accuracy": accuracy,
    "Precision": precision,
    "Recall": recall,
    "F1 Score": f1                                             
}

# Convert metrics dictionary to DataFrame for plotting
metrics_df = pd.DataFrame(list(classification_metrics.items()), columns=["Metric", "Score"])

# Plot the classification metrics
plt.figure(figsize=(8, 5))
sns.barplot(data=metrics_df, x="Metric", y="Score", palette="coolwarm")
plt.title("Classification Metrics for K-Nearest Neighbors Regression")
plt.ylabel("Score")
plt.ylim(0, 1)  # Assuming scores are within 0-1
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sanay\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
#  K-Nearest Neighbors Regression Performance:
# MSE: 1.5993200230040958, RMSE: 1.264642250995947, R²: 0.3602781606105594
# Accuracy: 1.0, Precision: 0.0, Recall: 0.0, F1 Score: 0.0
# C:\Users\sanay\AppData\Local\Temp\ipykernel_13848\342732279.py:80: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=metrics_df, x="Metric", y="Score", palette="coolwarm")

# %%
# 09 Polynomial Regression (2nd Degree)
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Load data
file_path = r"D:\B TECH COMPUTER SCIENCE AND ENGINEERING\SEMESTER 05\MACHINE LEARNING\ML PROJECT\EMBEDDINGS_GPT2.xlsx"
data = pd.read_excel(file_path)

# Features and target variable
X = data.iloc[:, 0:768]
y = data['Average_Marks']

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Model and threshold
model = make_pipeline(PolynomialFeatures(degree=2), LinearRegression())
threshold = 50

# Train and predict
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# Regression metrics
mse = mean_squared_error(y_test, y_pred)
rmse = mse ** 0.5
r2 = r2_score(y_test, y_pred)

# Convert predictions to binary classes based on threshold
y_pred_classes = (y_pred >= threshold).astype(int)
y_test_classes = (y_test >= threshold).astype(int)

# Classification metrics
accuracy = accuracy_score(y_test_classes, y_pred_classes)
precision = precision_score(y_test_classes, y_pred_classes, zero_division=0)
recall = recall_score(y_test_classes, y_pred_classes, zero_division=0)
f1 = f1_score(y_test_classes, y_pred_classes, zero_division=0)
conf_matrix = confusion_matrix(y_test_classes, y_pred_classes)

# Display regression metrics
print("Polynomial Regression (2nd Degree) Performance:")
print(f"MSE: {mse}, RMSE: {rmse}, R²: {r2}")
print(f"Accuracy: {accuracy}, Precision: {precision}, Recall: {recall}, F1 Score: {f1}")

# Plot confusion matrix with a colorful palette
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="YlGnBu", cbar=True, annot_kws={"size": 14},
            xticklabels=["Predicted Negative", "Predicted Positive"], 
            yticklabels=["Actual Negative", "Actual Positive"],
            linewidths=1, linecolor='black', square=True)

plt.xlabel("Predicted Class")
plt.ylabel("Actual Class")
plt.title("Confusion Matrix with Colors")
plt.show()

# Plot classification metrics
classification_metrics = {
    "Accuracy": accuracy,
    "Precision": precision,
    "Recall": recall,
    "F1 Score": f1                                             
}

# Convert metrics dictionary to DataFrame for plotting
metrics_df = pd.DataFrame(list(classification_metrics.items()), columns=["Metric", "Score"])

# Plot the classification metrics
plt.figure(figsize=(8, 5))
sns.barplot(data=metrics_df, x="Metric", y="Score", palette="coolwarm")
plt.title("Classification Metrics for Polynomial Regression (2nd Degree)")
plt.ylabel("Score")
plt.ylim(0, 1)  # Assuming scores are within 0-1
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Polynomial Regression (2nd Degree) Performance:
# MSE: 6.124210960606375e+18, RMSE: 2474714318.9884315, R²: -2.449660758432241e+18
# Accuracy: 0.5610328638497653, Precision: 0.0, Recall: 0.0, F1 Score: 0.0
# C:\Users\sanay\AppData\Local\Temp\ipykernel_13848\4013646883.py:82: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=metrics_df, x="Metric", y="Score", palette="coolwarm")

# %%
# 10 Decision Tree Regression
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Load data
file_path = r"D:\B TECH COMPUTER SCIENCE AND ENGINEERING\SEMESTER 05\MACHINE LEARNING\ML PROJECT\EMBEDDINGS_GPT2.xlsx"
data = pd.read_excel(file_path)

# Features and target variable
X = data.iloc[:, 0:768]
y = data['Average_Marks']

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Model and threshold
model = DecisionTreeRegressor()
threshold = 50

# Train and predict
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# Regression metrics
mse = mean_squared_error(y_test, y_pred)
rmse = mse ** 0.5
r2 = r2_score(y_test, y_pred)

# Convert predictions to binary classes based on threshold
y_pred_classes = (y_pred >= threshold).astype(int)
y_test_classes = (y_test >= threshold).astype(int)

# Classification metrics
accuracy = accuracy_score(y_test_classes, y_pred_classes)
precision = precision_score(y_test_classes, y_pred_classes, zero_division=0)
recall = recall_score(y_test_classes, y_pred_classes, zero_division=0)
f1 = f1_score(y_test_classes, y_pred_classes, zero_division=0)
conf_matrix = confusion_matrix(y_test_classes, y_pred_classes)

# Display regression metrics
print("Decision Tree Regression Performance:")
print(f"MSE: {mse}, RMSE: {rmse}, R²: {r2}")
print(f"Accuracy: {accuracy}, Precision: {precision}, Recall: {recall}, F1 Score: {f1}")

# Plot confusion matrix with a colorful palette
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="YlGnBu", cbar=True, annot_kws={"size": 14},
            xticklabels=["Predicted Negative", "Predicted Positive"], 
            yticklabels=["Actual Negative", "Actual Positive"],
            linewidths=1, linecolor='black', square=True)

plt.xlabel("Predicted Class")
plt.ylabel("Actual Class")
plt.title("Confusion Matrix with Colors")
plt.show()

# Plot classification metrics
classification_metrics = {
    "Accuracy": accuracy,
    "Precision": precision,
    "Recall": recall,
    "F1 Score": f1                                             
}

# Convert metrics dictionary to DataFrame for plotting
metrics_df = pd.DataFrame(list(classification_metrics.items()), columns=["Metric", "Score"])

# Plot the classification metrics
plt.figure(figsize=(8, 5))
sns.barplot(data=metrics_df, x="Metric", y="Score", palette="coolwarm")
plt.title("Classification Metrics for Decision Tree Regression")
plt.ylabel("Score")
plt.ylim(0, 1)  # Assuming scores are within 0-1
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Decision Tree Regression Performance:
# MSE: 2.9295029745340533, RMSE: 1.7115790880161084, R²: -0.171789888458717
# Accuracy: 1.0, Precision: 0.0, Recall: 0.0, F1 Score: 0.0
# C:\Users\sanay\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# C:\Users\sanay\AppData\Local\Temp\ipykernel_13848\1013750447.py:80: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=metrics_df, x="Metric", y="Score", palette="coolwarm")

# %% [markdown]
# OVERALL 10 ALGORITHMS PERFORMANCE ANALYSIS
#
# 01 Linear Regression Performance:
# MSE: 3.285151313307191, RMSE: 1.8124986381531962, R²: -0.31404785195772544
# Accuracy: 1.0, Precision: 0.0, Recall: 0.0, F1 Score: 0.0
#
# 02 Ridge Regression Performance:
# MSE: 2.044133358853745, RMSE: 1.4297319185265973, R²: 0.18235454225918601
# Accuracy: 1.0, Precision: 0.0, Recall: 0.0, F1 Score: 0.0
#
# 03 ElasticNet Regression Performance:
# MSE: 2.1142360393654758, RMSE: 1.4540412784255734, R²: 0.15431374049466018
# Accuracy: 1.0, Precision: 0.0, Recall: 0.0, F1 Score: 0.0
#
# 04 SVR Performance:
# MSE: 1.5811237084312642, RMSE: 1.2574274167645878, R²: 0.36755661624245706
# Accuracy: 1.0, Precision: 0.0, Recall: 0.0, F1 Score: 0.0
#
# 05 Lasso Regression Performance:
# MSE: 2.5114424253722762, RMSE: 1.5847531118039415, R²: -0.004567281576337789
# Accuracy: 1.0, Precision: 0.0, Recall: 0.0, F1 Score: 0.0
#
# 06 Random Forest Regression Performance:
# MSE: 1.6458583970731522, RMSE: 1.2829101282136455, R²: 0.3416629905173789
# Accuracy: 1.0, Precision: 0.0, Recall: 0.0, F1 Score: 0.0
#
# 07 Gradient Boosting Regression Performance:
# MSE: 1.636258132383184, RMSE: 1.2791630593412178, R²: 0.34550305935773273
# Accuracy: 1.0, Precision: 0.0, Recall: 0.0, F1 Score: 0.0
#
# 08 K-Nearest Neighbors Regression Performance:
# MSE: 1.5993200230040958, RMSE: 1.264642250995947, R²: 0.3602781606105594
# Accuracy: 1.0, Precision: 0.0, Recall: 0.0, F1 Score: 0.0
#
# 09 Polynomial Regression (2nd Degree) Performance:
# MSE: 6.124210960606375e+18, RMSE: 2474714318.9884315, R²: -2.449660758432241e+18
# Accuracy: 0.5610328638497653, Precision: 0.0, Recall: 0.0, F1 Score: 0.0
#
# 10 Decision Tree Regression Performance:
# MSE: 2.9295029745340533, RMSE: 1.7115790880161084, R²: -0.171789888458717
# Accuracy: 1.0, Precision: 0.0, Recall: 0.0, F1 Score: 0.0
